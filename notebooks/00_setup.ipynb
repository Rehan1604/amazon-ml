# %%
import pandas as pd, os
os.makedirs("../work", exist_ok=True)
for split, src in [("tr", "train"), ("te", "test")]:
    for i in [1, 2, 3]:
        df = pd.read_csv(f"../dataset/{src}/{src}_source{i}.tsv", sep="\t", dtype=str, keep_default_na=False)
        df.to_pickle(f"../work/{split}_s{i}.pkl"); print("saved", split, i)
gt = pd.read_csv("../dataset/train/train_ground_truth.tsv", sep="\t", dtype=str, keep_default_na=False)
gt.to_pickle("../work/tr_gt.pkl"); print("saved gt")
# Out:
# saved tr 1
# saved tr 2
# saved tr 3
# saved te 1
# saved te 2
# saved te 3
# saved gt
